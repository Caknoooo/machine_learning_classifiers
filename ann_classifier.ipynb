# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Data Processing
liver_df = pd.read_csv("../data/liver_cirrhosis.csv")

# Define numerical and binary columns
num_cols = ['N_Days', 'Age', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin']
binary_cols = ['Sex', 'Ascites', 'Hepatomegaly', 'Spiders']

# Convert categorical columns to numerical
liver_df['Sex'] = liver_df['Sex'].map({'M': 0, 'F': 1})
liver_df['Ascites'] = liver_df['Ascites'].map({'N': 0, 'Y': 1})
liver_df['Hepatomegaly'] = liver_df['Hepatomegaly'].map({'N': 0, 'Y': 1})
liver_df['Spiders'] = liver_df['Spiders'].map({'N': 0, 'Y': 1})
liver_df['Edema'] = liver_df['Edema'].map({'N': 0, 'S': 1, 'Y': 2})
liver_df['Status'] = liver_df['Status'].astype('category').cat.codes
liver_df['Drug'] = liver_df['Drug'].astype('category').cat.codes

# Remove duplicates
liver_df.drop_duplicates(inplace=True)

# Filter outliers
liver_df = liver_df[liver_df['N_Days'] <= 3000]
liver_df = liver_df[liver_df['Age'] <= 22500]
liver_df = liver_df[liver_df['Bilirubin'] <= 5]
liver_df = liver_df[liver_df['Cholesterol'] <= 500]
liver_df = liver_df[(liver_df['Albumin'] >= 3) & (liver_df['Albumin'] <= 4)]
liver_df = liver_df[liver_df['Copper'] <= 400]
liver_df = liver_df[liver_df['Alk_Phos'] <= 2000]
liver_df = liver_df[liver_df['SGOT'] <= 350]
liver_df = liver_df[liver_df['Tryglicerides'] <= 400]
liver_df = liver_df[liver_df['Platelets'] <= 300]
liver_df = liver_df[liver_df['Prothrombin'] <= 16]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Data Processing
# ----> 2 liver_df = pd.read_csv("../data/liver_cirrhosis.csv")
#       4 # Define numerical and binary columns
#       5 num_cols = ['N_Days', 'Age', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin']
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/liver_cirrhosis.csv'

# %%
# Splitting the data
X = liver_df.drop('Stage', axis=1)
y = liver_df['Stage']

# Ensure labels are within the valid range
print("Unique target values before adjustment:", y.unique())
if y.max() >= 3:
    y = y - 1
print("Unique target values after adjustment:", y.unique())

# Perform stratified sampling to maintain the distribution of classes in train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Scaling numerical features
scaler = StandardScaler()
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])
# Out:
# Unique target values before adjustment: [2 1 3]
# Unique target values after adjustment: [1 0 2]

# %%
# Building the ANN model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(3, activation='softmax'))  # Assuming 3 classes for the target

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=10, validation_data=(X_test, y_test))

# Plotting training history
plt.figure(figsize=(8, 6))
sns.lineplot(data=history.history)
plt.title("Model Training Progress")
plt.xlabel("Epochs")
plt.ylabel("Value")
plt.legend(labels=history.history.keys(), title='Metrics')
plt.tight_layout()
plt.show()

# Making predictions
y_pred = np.argmax(model.predict(X_test), axis=1)

# Classification report
print(classification_report(y_test, y_pred))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=['1', '2', '3'], yticklabels=['1', '2', '3'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 231/231 [==============================] - 2s 4ms/step - loss: 1.0118 - accuracy: 0.4723 - val_loss: 0.8930 - val_accuracy: 0.5657
# Epoch 2/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.8605 - accuracy: 0.5975 - val_loss: 0.8432 - val_accuracy: 0.6003
# Epoch 3/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.7994 - accuracy: 0.6352 - val_loss: 0.8156 - val_accuracy: 0.6125
# Epoch 4/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.7496 - accuracy: 0.6564 - val_loss: 0.7924 - val_accuracy: 0.6315
# Epoch 5/100
# 231/231 [==============================] - 1s 2ms/step - loss: 0.7102 - accuracy: 0.6880 - val_loss: 0.7716 - val_accuracy: 0.6505
# Epoch 6/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.6692 - accuracy: 0.7045 - val_loss: 0.7693 - val_accuracy: 0.6298
# Epoch 7/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.6386 - accuracy: 0.7210 - val_loss: 0.7987 - val_accuracy: 0.6401
# Epoch 8/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.6175 - accuracy: 0.7309 - val_loss: 0.7940 - val_accuracy: 0.6453
# Epoch 9/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.5936 - accuracy: 0.7504 - val_loss: 0.7408 - val_accuracy: 0.6782
# Epoch 10/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.5693 - accuracy: 0.7565 - val_loss: 0.7816 - val_accuracy: 0.6453
# Epoch 11/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.5407 - accuracy: 0.7751 - val_loss: 0.7609 - val_accuracy: 0.6730
# Epoch 12/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.5226 - accuracy: 0.7799 - val_loss: 0.7357 - val_accuracy: 0.6851
# Epoch 13/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.5044 - accuracy: 0.7886 - val_loss: 0.7540 - val_accuracy: 0.6747
# Epoch 14/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.4922 - accuracy: 0.8003 - val_loss: 0.7543 - val_accuracy: 0.6834
# Epoch 15/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.4606 - accuracy: 0.8072 - val_loss: 0.7582 - val_accuracy: 0.6972
# Epoch 16/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.4474 - accuracy: 0.8141 - val_loss: 0.7677 - val_accuracy: 0.6730
# Epoch 17/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.4358 - accuracy: 0.8219 - val_loss: 0.7990 - val_accuracy: 0.6713
# Epoch 18/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.4240 - accuracy: 0.8228 - val_loss: 0.7779 - val_accuracy: 0.6851
# Epoch 19/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.4102 - accuracy: 0.8406 - val_loss: 0.7930 - val_accuracy: 0.6869
# Epoch 20/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.3954 - accuracy: 0.8462 - val_loss: 0.7982 - val_accuracy: 0.6817
# Epoch 21/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.3859 - accuracy: 0.8449 - val_loss: 0.8285 - val_accuracy: 0.6782
# Epoch 22/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.3690 - accuracy: 0.8501 - val_loss: 0.8397 - val_accuracy: 0.6696
# Epoch 23/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.3503 - accuracy: 0.8618 - val_loss: 0.8952 - val_accuracy: 0.6765
# Epoch 24/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.3506 - accuracy: 0.8618 - val_loss: 0.8556 - val_accuracy: 0.7007
# Epoch 25/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.3342 - accuracy: 0.8726 - val_loss: 0.8564 - val_accuracy: 0.6903
# Epoch 26/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.3276 - accuracy: 0.8765 - val_loss: 0.8713 - val_accuracy: 0.6799
# Epoch 27/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.3179 - accuracy: 0.8752 - val_loss: 0.8681 - val_accuracy: 0.6903
# Epoch 28/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.3059 - accuracy: 0.8873 - val_loss: 0.9274 - val_accuracy: 0.6834
# Epoch 29/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.2928 - accuracy: 0.8899 - val_loss: 0.8759 - val_accuracy: 0.6938
# Epoch 30/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.2952 - accuracy: 0.8808 - val_loss: 0.9076 - val_accuracy: 0.6817
# Epoch 31/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.2830 - accuracy: 0.8921 - val_loss: 0.9625 - val_accuracy: 0.7059
# Epoch 32/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.2750 - accuracy: 0.8973 - val_loss: 0.9778 - val_accuracy: 0.6834
# Epoch 33/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.2724 - accuracy: 0.9025 - val_loss: 0.9555 - val_accuracy: 0.6990
# Epoch 34/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.2648 - accuracy: 0.9016 - val_loss: 1.0009 - val_accuracy: 0.6903
# Epoch 35/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.2500 - accuracy: 0.9077 - val_loss: 1.0112 - val_accuracy: 0.6696
# Epoch 36/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.2467 - accuracy: 0.9116 - val_loss: 0.9903 - val_accuracy: 0.6799
# Epoch 37/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.2408 - accuracy: 0.9129 - val_loss: 1.0006 - val_accuracy: 0.6851
# Epoch 38/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.2298 - accuracy: 0.9151 - val_loss: 1.0787 - val_accuracy: 0.7007
# Epoch 39/100
# 231/231 [==============================] - 1s 2ms/step - loss: 0.2278 - accuracy: 0.9168 - val_loss: 1.0293 - val_accuracy: 0.7076
# Epoch 40/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.2221 - accuracy: 0.9216 - val_loss: 1.1367 - val_accuracy: 0.6696
# Epoch 41/100
# 231/231 [==============================] - 1s 2ms/step - loss: 0.2186 - accuracy: 0.9194 - val_loss: 1.1011 - val_accuracy: 0.6799
# Epoch 42/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.2111 - accuracy: 0.9237 - val_loss: 1.1085 - val_accuracy: 0.6851
# Epoch 43/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1998 - accuracy: 0.9281 - val_loss: 1.1195 - val_accuracy: 0.6765
# Epoch 44/100
# 231/231 [==============================] - 1s 2ms/step - loss: 0.1954 - accuracy: 0.9233 - val_loss: 1.1716 - val_accuracy: 0.6713
# Epoch 45/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1932 - accuracy: 0.9324 - val_loss: 1.1962 - val_accuracy: 0.6851
# Epoch 46/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1918 - accuracy: 0.9268 - val_loss: 1.1417 - val_accuracy: 0.6799
# Epoch 47/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1897 - accuracy: 0.9320 - val_loss: 1.1625 - val_accuracy: 0.6990
# Epoch 48/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1749 - accuracy: 0.9363 - val_loss: 1.2138 - val_accuracy: 0.6799
# Epoch 49/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1768 - accuracy: 0.9363 - val_loss: 1.2509 - val_accuracy: 0.6920
# Epoch 50/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1782 - accuracy: 0.9328 - val_loss: 1.2623 - val_accuracy: 0.6730
# Epoch 51/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1762 - accuracy: 0.9315 - val_loss: 1.2584 - val_accuracy: 0.6817
# Epoch 52/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1646 - accuracy: 0.9419 - val_loss: 1.2628 - val_accuracy: 0.7042
# Epoch 53/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1645 - accuracy: 0.9432 - val_loss: 1.2227 - val_accuracy: 0.6955
# Epoch 54/100
# 231/231 [==============================] - 1s 2ms/step - loss: 0.1540 - accuracy: 0.9454 - val_loss: 1.3270 - val_accuracy: 0.6886
# Epoch 55/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1493 - accuracy: 0.9493 - val_loss: 1.3346 - val_accuracy: 0.7059
# Epoch 56/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1597 - accuracy: 0.9406 - val_loss: 1.3236 - val_accuracy: 0.6886
# Epoch 57/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1520 - accuracy: 0.9489 - val_loss: 1.3522 - val_accuracy: 0.7007
# Epoch 58/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1460 - accuracy: 0.9484 - val_loss: 1.3556 - val_accuracy: 0.7076
# Epoch 59/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1384 - accuracy: 0.9493 - val_loss: 1.4786 - val_accuracy: 0.6817
# Epoch 60/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1489 - accuracy: 0.9458 - val_loss: 1.4343 - val_accuracy: 0.6920
# Epoch 61/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1294 - accuracy: 0.9528 - val_loss: 1.3754 - val_accuracy: 0.6869
# Epoch 62/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1260 - accuracy: 0.9558 - val_loss: 1.4145 - val_accuracy: 0.6713
# Epoch 63/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1322 - accuracy: 0.9554 - val_loss: 1.4910 - val_accuracy: 0.6713
# Epoch 64/100
# 231/231 [==============================] - 1s 2ms/step - loss: 0.1203 - accuracy: 0.9584 - val_loss: 1.4719 - val_accuracy: 0.7042
# Epoch 65/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.1207 - accuracy: 0.9567 - val_loss: 1.5488 - val_accuracy: 0.6678
# Epoch 66/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1388 - accuracy: 0.9471 - val_loss: 1.5512 - val_accuracy: 0.7007
# Epoch 67/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1300 - accuracy: 0.9515 - val_loss: 1.5504 - val_accuracy: 0.6869
# Epoch 68/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1207 - accuracy: 0.9580 - val_loss: 1.5123 - val_accuracy: 0.6938
# Epoch 69/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1171 - accuracy: 0.9575 - val_loss: 1.5638 - val_accuracy: 0.6696
# Epoch 70/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1212 - accuracy: 0.9541 - val_loss: 1.5304 - val_accuracy: 0.6869
# Epoch 71/100
# 231/231 [==============================] - 1s 2ms/step - loss: 0.1054 - accuracy: 0.9675 - val_loss: 1.5241 - val_accuracy: 0.6955
# Epoch 72/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1134 - accuracy: 0.9623 - val_loss: 1.6185 - val_accuracy: 0.7093
# Epoch 73/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1162 - accuracy: 0.9584 - val_loss: 1.6080 - val_accuracy: 0.7007
# Epoch 74/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1149 - accuracy: 0.9614 - val_loss: 1.5475 - val_accuracy: 0.6972
# Epoch 75/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1040 - accuracy: 0.9653 - val_loss: 1.6286 - val_accuracy: 0.6903
# Epoch 76/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0982 - accuracy: 0.9666 - val_loss: 1.6173 - val_accuracy: 0.6938
# Epoch 77/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.1110 - accuracy: 0.9627 - val_loss: 1.6211 - val_accuracy: 0.7007
# Epoch 78/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1317 - accuracy: 0.9545 - val_loss: 1.6986 - val_accuracy: 0.6765
# Epoch 79/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1044 - accuracy: 0.9649 - val_loss: 1.6664 - val_accuracy: 0.6938
# Epoch 80/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0908 - accuracy: 0.9718 - val_loss: 1.6161 - val_accuracy: 0.6955
# Epoch 81/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.1023 - accuracy: 0.9658 - val_loss: 1.6688 - val_accuracy: 0.6938
# Epoch 82/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1140 - accuracy: 0.9580 - val_loss: 1.6853 - val_accuracy: 0.6990
# Epoch 83/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1062 - accuracy: 0.9588 - val_loss: 1.7235 - val_accuracy: 0.7007
# Epoch 84/100
# 231/231 [==============================] - 1s 5ms/step - loss: 0.0962 - accuracy: 0.9679 - val_loss: 1.7361 - val_accuracy: 0.6955
# Epoch 85/100
# 231/231 [==============================] - 1s 5ms/step - loss: 0.0958 - accuracy: 0.9666 - val_loss: 1.7273 - val_accuracy: 0.6938
# Epoch 86/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.0936 - accuracy: 0.9662 - val_loss: 1.7422 - val_accuracy: 0.7145
# Epoch 87/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.1020 - accuracy: 0.9675 - val_loss: 1.7651 - val_accuracy: 0.6920
# Epoch 88/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0962 - accuracy: 0.9679 - val_loss: 1.7339 - val_accuracy: 0.6955
# Epoch 89/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0942 - accuracy: 0.9705 - val_loss: 1.7260 - val_accuracy: 0.7024
# Epoch 90/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0858 - accuracy: 0.9736 - val_loss: 1.8154 - val_accuracy: 0.6990
# Epoch 91/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0910 - accuracy: 0.9731 - val_loss: 1.8118 - val_accuracy: 0.6972
# Epoch 92/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0882 - accuracy: 0.9705 - val_loss: 1.8007 - val_accuracy: 0.7024
# Epoch 93/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.1253 - accuracy: 0.9545 - val_loss: 1.7197 - val_accuracy: 0.7059
# Epoch 94/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0900 - accuracy: 0.9692 - val_loss: 1.7800 - val_accuracy: 0.6851
# Epoch 95/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0840 - accuracy: 0.9727 - val_loss: 1.7314 - val_accuracy: 0.7128
# Epoch 96/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0892 - accuracy: 0.9710 - val_loss: 1.7978 - val_accuracy: 0.7093
# Epoch 97/100
# 231/231 [==============================] - 1s 4ms/step - loss: 0.0962 - accuracy: 0.9688 - val_loss: 1.8190 - val_accuracy: 0.7024
# Epoch 98/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0883 - accuracy: 0.9723 - val_loss: 1.7863 - val_accuracy: 0.7093
# Epoch 99/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0822 - accuracy: 0.9744 - val_loss: 1.8120 - val_accuracy: 0.7076
# Epoch 100/100
# 231/231 [==============================] - 1s 3ms/step - loss: 0.0865 - accuracy: 0.9662 - val_loss: 1.8702 - val_accuracy: 0.7145
# 19/19 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.71      0.65      0.68       181
#            1       0.69      0.67      0.68       206
#            2       0.74      0.82      0.78       191
#
#     accuracy                           0.71       578
#    macro avg       0.71      0.71      0.71       578
# weighted avg       0.71      0.71      0.71       578
